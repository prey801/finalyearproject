# %% [markdown]
# # MedScope AI - Colab Training
#
# Run this notebook on Google Colab with a T4 GPU.

# %%
# !git clone https://github.com/muuo/finalyearproject.git
# %cd finalyearproject

# %%
# !pip install -r backend/requirements.txt
# !pip install -r models/requirements.txt
# !pip install pytest qdrant-client

# %% [markdown]
# ## 1. Prepare Data
# Run the data split script if the raw data is available in `data/raw/`.

# %%
# !python3 -m scripts.split_data

# %% [markdown]
# ## 2. Train YOLOv11 (Object Detection)

# %%
# !python3 -m scripts.train_yolo --data data/raw/roboflow_malaria/data.yaml --epochs 100 --batch 16 --device 0

# %% [markdown]
# ## 3. Train Swin Transformer (Disease Classification)

# %%
# !python3 -m scripts.train_classification --data_dir data/ --epochs 20 --batch 32 --device 0
